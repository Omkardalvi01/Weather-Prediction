# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('weather_australia.csv')
data.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
# ...

# %%
data['MinTemp'].interpolate(method='linear',inplace=True)
data['MaxTemp'].interpolate(method='linear',inplace=True)
#Min and Max temp does not show alot of deviation
data['Rainfall'] = data['Rainfall'].fillna(data['Rainfall'].mean)
#exchanging null with mean
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\1850072956.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['MinTemp'].interpolate(method='linear',inplace=True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\1850072956.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data['Cloud3pm'].fillna(-1,inplace = True)
data['Cloud9am'].fillna(-1, inplace=True)
#null values are filled in with place holders as they are categorical and have large quantity of null values
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\203849133.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Cloud3pm'].fillna(-1,inplace = True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\203849133.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
data['Temp3pm'].interpolate(method='linear', inplace=True)
data['Temp9am'].interpolate(method='linear',inplace=True)
# data does show alot of diviation so replacing with liner interpolate
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\3998269750.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Temp3pm'].interpolate(method='linear', inplace=True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\3998269750.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.dropna(subset=['RainToday'], inplace=True)

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp   Evaporation      Sunshine  \
# count  140787.000000  140787.000000  81093.000000  73982.000000
# mean       12.187995      23.236651      5.472516      7.630540
# std         6.401267       7.113958      4.189132      3.781729
# min        -8.500000      -4.800000      0.000000      0.000000
# 25%         7.600000      17.900000      2.600000      4.900000
# 50%        12.000000      22.600000      4.800000      8.500000
# 75%        16.800000      28.300000      7.400000     10.700000
# max        33.900000      48.100000    145.000000     14.500000
#
#        WindGustSpeed   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  131682.000000  139732.000000  138256.000000  139270.000000
# mean       39.970520      13.990496      18.631141      68.826833
# std        13.578201       8.886210       8.798096      19.063650
# min         6.000000       0.000000       0.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 0 to 142192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           140787 non-null  object
#  1   Location       140787 non-null  object
#  2   MinTemp        140787 non-null  float64
#  3   MaxTemp        140787 non-null  float64
#  4   Rainfall       140787 non-null  object
#  5   Evaporation    81093 non-null   float64
#  6   Sunshine       73982 non-null   float64
#  7   WindGustDir    131624 non-null  object
#  8   WindGustSpeed  131682 non-null  float64
#  9   WindDir9am     131127 non-null  object
#  10  WindDir3pm     137117 non-null  object
#  11  WindSpeed9am   139732 non-null  float64
#  12  WindSpeed3pm   138256 non-null  float64
#  13  Humidity9am    139270 non-null  float64
#  14  Humidity3pm    137286 non-null  float64
#  15  Pressure9am    127044 non-null  float64
#  16  Pressure3pm    127018 non-null  float64
# ...

# %%
data.corr(numeric_only=True)
# Out:
#                 MinTemp   MaxTemp  Evaporation  Sunshine  WindGustSpeed  \
# MinTemp        1.000000  0.736285     0.467226  0.073270       0.177642
# MaxTemp        0.736285  1.000000     0.588849  0.470260       0.068473
# Evaporation    0.467226  0.588849     1.000000  0.366659       0.203396
# Sunshine       0.073270  0.470260     0.366659  1.000000      -0.032196
# WindGustSpeed  0.177642  0.068473     0.203396 -0.032196       1.000000
# WindSpeed9am   0.175279  0.014287     0.194398  0.009188       0.604513
# WindSpeed3pm   0.175309  0.050880     0.129166  0.056480       0.686881
# Humidity9am   -0.234222 -0.505886    -0.506055 -0.492784      -0.215117
# Humidity3pm    0.005575 -0.509654    -0.393149 -0.629638      -0.026631
# Pressure9am   -0.451488 -0.331919    -0.269850  0.041071      -0.457710
# Pressure3pm   -0.462251 -0.427195    -0.293098 -0.020276      -0.412879
# Cloud9am       0.160879 -0.094716    -0.119980 -0.534800       0.077583
# ...

# %%
data.drop(columns=['Evaporation','Sunshine'], axis=1, inplace=True)
#evaporation and sunshine has 50% null values so i removed them

# %%
data['WindGustSpeed'].fillna(data['WindGustSpeed'].mean(), inplace=True)
#wind gust speed is continous so replacing value with mean
data['WindGustDir'].fillna(data['WindGustDir'].mode()[0], inplace=True)
data['WindDir9am'].fillna(data['WindDir9am'].mode()[0], inplace=True)
data['WindDir3pm'].fillna(data['WindDir3pm'].mode()[0], inplace=True)
#data is categorical so replacing with their mode
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\143832388.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['WindGustSpeed'].fillna(data['WindGustSpeed'].mean(), inplace=True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\143832388.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data['WindSpeed9am'].interpolate(method='linear',inplace=True)
data['WindSpeed3pm'].interpolate(method='linear',inplace=True)
data['Humidity9am'].interpolate(method='linear', inplace=True)
data['Humidity3pm'].interpolate(method='linear', inplace=True)
#data does not show alot of deviation so replacing with average of values around
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\2549473051.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['WindSpeed9am'].interpolate(method='linear',inplace=True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\2549473051.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data['Pressure3pm'].interpolate(method='linear',inplace=True)
data['Pressure9am'].interpolate(method='linear', inplace=True)
#data does not show alot of deviation so replacing with average of values around
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\2329946773.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Pressure3pm'].interpolate(method='linear',inplace=True)
# C:\Users\smile\AppData\Local\Temp\ipykernel_24656\2329946773.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 0 to 142192
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           140787 non-null  object
#  1   Location       140787 non-null  object
#  2   MinTemp        140787 non-null  float64
#  3   MaxTemp        140787 non-null  float64
#  4   Rainfall       140787 non-null  object
#  5   WindGustDir    140787 non-null  object
#  6   WindGustSpeed  140787 non-null  float64
#  7   WindDir9am     140787 non-null  object
#  8   WindDir3pm     140787 non-null  object
#  9   WindSpeed9am   140787 non-null  float64
#  10  WindSpeed3pm   140787 non-null  float64
#  11  Humidity9am    140787 non-null  float64
#  12  Humidity3pm    140787 non-null  float64
#  13  Pressure9am    140787 non-null  float64
#  14  Pressure3pm    140787 non-null  float64
#  15  Cloud9am       140787 non-null  float64
#  16  Cloud3pm       140787 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data['Rainfall'] = pd.to_numeric(data['Rainfall'])

# %%
data.drop(columns=['Date'],inplace=True)
#converting to right datatype

# %%
X = data.drop(['RainTomorrow','Location'],axis=1)
Y = data['RainTomorrow']
#drop location has little no effect on accuracy

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Humidity3pm', y='Rainfall', data=data, alpha=0.5, hue='RainTomorrow')
plt.title('Humidity at 3pm vs Rainfall')
plt.xlabel('Humidity at 3pm')
plt.ylabel('Rainfall')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Humidity9am', y='Rainfall', data=data, alpha=0.5, hue='RainTomorrow')
plt.title('Humidity at 9 am vs Rainfall')
plt.xlabel('Humidity at 9 am')
plt.ylabel('Rainfall')
plt.show()
#there is more rainfall when humidity is higher and more chances of it raining the next day

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='MaxTemp', y='Rainfall', data=data, alpha=0.5,  hue='RainTomorrow')
plt.title('MaxTemp vs Rainfall')
plt.xlabel('MaxTemp')
plt.ylabel('Rainfall')
plt.show()
#shows normal disrtribution

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Pressure9am', y='Rainfall', data=data, alpha=0.5,  hue='RainTomorrow')
plt.title('Pressure vs Rainfall')
plt.xlabel('Pressure')
plt.ylabel('Rainfall')
plt.show()
#shows normal distribution

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='WindGustSpeed', y='Rainfall', data=data, alpha=0.5,  hue='RainTomorrow')
plt.title('Pressure vs Rainfall')
plt.xlabel('Pressure')
plt.ylabel('Rainfall')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size = 0.8)

# %%
Y_train
# Out:
# 96592     Yes
# 1235      Yes
# 21551     Yes
# 43474      No
# 98674     Yes
#          ...
# 76958      No
# 22025      No
# 106390     No
# 48970      No
# 121415     No
# Name: RainTomorrow, Length: 112629, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoder = LabelEncoder()
Y_train= lbl_encoder.fit_transform(Y_train)
Y_test = lbl_encoder.transform(Y_test)
#label encoding for target

# %%
Y_train = pd.Series(Y_train)

# %%
pd.concat([X_train.reset_index(drop=True),Y_train.reset_index(drop=True)],axis=1).corr(numeric_only=True)
# Out:
#                 MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# MinTemp        1.000000  0.736502  0.103566       0.172177      0.172072
# MaxTemp        0.736502  1.000000 -0.076891       0.064319      0.011523
# Rainfall       0.103566 -0.076891  1.000000       0.125862      0.084939
# WindGustSpeed  0.172177  0.064319  0.125862       1.000000      0.577518
# WindSpeed9am   0.172072  0.011523  0.084939       0.577518      1.000000
# WindSpeed3pm   0.174212  0.048364  0.055859       0.647445      0.501646
# Humidity9am   -0.233440 -0.502529  0.223435      -0.206040     -0.267698
# Humidity3pm   -0.000553 -0.507189  0.253420      -0.022659     -0.027625
# Pressure9am   -0.400053 -0.277950 -0.159093      -0.397877     -0.169839
# Pressure3pm   -0.413334 -0.367289 -0.120118      -0.355005     -0.117267
# Cloud9am       0.161429 -0.093965  0.138887       0.072914      0.099396
# Cloud3pm       0.123091 -0.086019  0.115646       0.096022      0.117501
# ...

# %%
cat_columns = []
for column in X.columns:
    if data[column].dtype == 'object':
        cat_columns.append(column)
cat_columns
# Out:
# ['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot = OneHotEncoder(sparse_output=False)
one_hot_train_df = one_hot.fit_transform(X_train[cat_columns])
one_hot_train = pd.DataFrame(one_hot_train_df, columns=one_hot.get_feature_names_out(cat_columns))
X_train= pd.concat([X_train.reset_index(drop=True), one_hot_train.reset_index(drop=True)],axis=1)
X_train.drop(columns=cat_columns,inplace=True)
#one hot encoding training categorical values

# %%
one_hot_test_df = one_hot.transform(X_test[cat_columns])
one_hot_test = pd.DataFrame(one_hot_test_df, columns=one_hot.get_feature_names_out(cat_columns))
X_test= pd.concat([X_test.reset_index(drop=True), one_hot_test.reset_index(drop=True)],axis=1)
X_test.drop(columns=cat_columns,inplace=True)
#one hot encoding testing categorical values

# %%
X_train.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# WindGustSpeed     0
# WindSpeed9am      0
#                  ..
# WindDir3pm_W      0
# WindDir3pm_WNW    0
# WindDir3pm_WSW    0
# RainToday_No      0
# RainToday_Yes     0
# Length: 65, dtype: int64

# %%
X_train.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RISK_MM',
#        'WindGustDir_E', 'WindGustDir_ENE', 'WindGustDir_ESE', 'WindGustDir_N',
#        'WindGustDir_NE', 'WindGustDir_NNE', 'WindGustDir_NNW',
#        'WindGustDir_NW', 'WindGustDir_S', 'WindGustDir_SE', 'WindGustDir_SSE',
#        'WindGustDir_SSW', 'WindGustDir_SW', 'WindGustDir_W', 'WindGustDir_WNW',
#        'WindGustDir_WSW', 'WindDir9am_E', 'WindDir9am_ENE', 'WindDir9am_ESE',
#        'WindDir9am_N', 'WindDir9am_NE', 'WindDir9am_NNE', 'WindDir9am_NNW',
#        'WindDir9am_NW', 'WindDir9am_S', 'WindDir9am_SE', 'WindDir9am_SSE',
#        'WindDir9am_SSW', 'WindDir9am_SW', 'WindDir9am_W', 'WindDir9am_WNW',
#        'WindDir9am_WSW', 'WindDir3pm_E', 'WindDir3pm_ENE', 'WindDir3pm_ESE',
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
X_train_norm = Scaler.fit_transform(X_train)
X_test_norm = Scaler.transform(X_test)
#performing scaling on data

# %%
from sklearn.decomposition import PCA
pca = PCA()
prpl_comp_x = pca.fit_transform(X_train_norm)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('num_of_comp')
plt.ylabel('variance_explained')
plt.title('Scree plot')
plt.show()
#still require alot of features to explain data so i didn't seem necessary to use it

# %%
# pca = PCA(n_components=40)
# X_train_principle = pca.fit_transform(X_train_norm)
# X_test_principle = pca.transform(X_test_norm)
# pca.explained_variance_ratio_.sum()

# %%
from sklearn.linear_model import  LogisticRegression
model = LogisticRegression(penalty='l2')
model.fit(X_train_norm,Y_train)
prediction = model.predict(X_train_norm)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(prediction, Y_train)
print(f'Confusion Matrix:\n {cm}')
print(classification_report(Y_train, prediction))
# Out:
# Confusion Matrix:
#  [[87653    57]
#  [    0 24919]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87653
#            1       1.00      1.00      1.00     24976
#
#     accuracy                           1.00    112629
#    macro avg       1.00      1.00      1.00    112629
# weighted avg       1.00      1.00      1.00    112629

# %%
prediction = model.predict(X_test_norm)
cm = confusion_matrix(prediction, Y_test)
print(f'Confusion Matrix:\n {cm}')
print(classification_report(Y_test, prediction))
# Out:
# Confusion Matrix:
#  [[21933    17]
#  [    0  6208]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21933
#            1       1.00      1.00      1.00      6225
#
#     accuracy                           1.00     28158
#    macro avg       1.00      1.00      1.00     28158
# weighted avg       1.00      1.00      1.00     28158

# %%
import pickle
with open('model.pkl','wb') as file:
    pickle.dump((model,Scaler,one_hot), file)
